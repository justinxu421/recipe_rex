# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %%
from serve_recs_ucb import UCBRecSys
rec_sys = UCBRecSys('desserts', 'desserts_filter')

urls, titles, image_paths = rec_sys.sample_urls(4)
print(urls)
print(image_paths)

# rec_sys.plot_images(image_paths)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-236a5f41e791> in <module>
#       1 from serve_recs_ucb import UCBRecSys
# ----> 2 rec_sys = UCBRecSys('desserts', 'desserts_filter')
#       3
#       4 urls, titles, image_paths = rec_sys.sample_urls(4)
#       5 print(urls)
#
# ~/recipe_rex/serve_recs_ucb.py in __init__(self, folder, file)
#      14         self.url_index_mapping = pd.read_csv(f'clean_data/{folder}/{file}_url_index_mapping.csv', index_col = 'url')
#      15
# ---> 16         self.meat_labels = pd.read_csv(f'clean_data/{folder}/meat_labels.csv', index_col = 'url').loc[self.embeddings_df_scaled.index]
#      17         self.starch_labels = pd.read_csv(f'clean_data/{folder}/starch_labels.csv', index_col = 'url').loc[self.embeddings_df_scaled.index]
#      18         # self.taste_labels = pd.read_csv('clean_data/mains/nutrient_features.csv', index_col = 'url')
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1313
#    1314                 with option_context("display.max_seq_items", 10, "display.width", 80):
# -> 1315                     raise KeyError(
#    1316                         "Passing list-likes to .loc or [] with any missing labels "
#    1317                         "is no longer supported. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Index(['https://www.justonecookbook.com/basque-burnt-cheesecake/',\n       'https://www.justonecookbook.com/panettone-bread-pudding/',\n       'https://www.justonecookbook.com/matcha-basque-cheesecake/',\n       'https://omnivorescookbook.com/eight-treasure-rice/',\n       'https://omnivorescookbook.com/mango-sago/',\n       ...\n       'https://omnivorescookbook.com/steamed-custard-buns/',\n       'https://omnivorescookbook.com/baked-bbq-pork-buns/',\n       'https://omnivorescookbook.com/chinese-egg-cake/',\n       'https://omnivorescookbook.com/dan-huang-su/',\n       'https://omnivorescookbook.com/sesame-checkerboard-cookies/'],\n      dtype='object', name='url', length=128). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
rec_sys.counts, rec_sys.totals
# Out:
# ({'poultry': 2,
#   'beef': 1,
#   'pork': 1,
#   'fish': 1,
#   'seafood': 0,
#   'lamb': 0,
#   'veg': 0},
#  {'poultry': 0,
#   'beef': 0,
#   'pork': 0,
#   'fish': 0,
#   'seafood': 0,
#   'lamb': 0,
#   'veg': 0})

# %%
for i in range(10):
    urls, titles, pics = rec_sys.sample_urls(4)
    rec_sys.update_meat_values(urls[0], urls)
# Out:
# ['beef', 'seafood', 'lamb', 'veg']
# ['poultry', 'pork', 'fish', 'seafood']
# ['seafood', 'lamb', 'veg', 'beef']
# ['seafood', 'fish', 'lamb', 'veg']
# ['poultry', 'seafood', 'pork', 'seafood']
# ['seafood', 'poultry', 'lamb', 'veg']
# ['seafood', 'poultry', 'pork', 'beef']
# ['lamb', 'seafood', 'veg', 'seafood']
# ['poultry', 'lamb', 'beef', 'lamb']
# ['poultry', 'poultry', 'seafood', 'fish']

# %%
rec_sys.get_confidence_df()
# Out:
# poultry    0.642857
# beef       0.125000
# pork       0.400000
# fish       0.000000
# seafood    0.363636
# lamb       0.142857
# veg        0.000000
# Name: val, dtype: float64

# %%
# sample some urls
urls = ['https://omnivorescookbook.com/chinese-egg-rolls/',
       'https://glebekitchen.com/miso-ramen-with-chashu-pork/',
       'https://omnivorescookbook.com/pineapple-buns/',
       'https://omnivorescookbook.com/easy-swiss-chard-stir-fry/',
       'https://thewoksoflife.com/stuffed-chicken-breast-sticky-rice/',
       'https://glebekitchen.com/spicy-miso-grilled-chicken/',
       'https://thewoksoflife.com/shrimp-lo-mein/',
       'https://thewoksoflife.com/stir-fried-cabbage-glass-noodles/',
       'https://glebekitchen.com/indian-restaurant-madras-curry/',
       'https://thewoksoflife.com/honey-sriracha-roasted-brussels-sprouts/']

rec_urls, rec_titles, recs_image_paths = rec_sys.get_recs(urls)
print(rec_urls)
print(rec_titles)
print(recs_image_paths)

rec_sys.plot_images(recs_image_paths)
# Out:
# Index(['poultry', 'pork'], dtype='object')
# 605
# Index(['https://glebekitchen.com/miso-chicken-with-maple-and-ginger/',
#        'https://glebekitchen.com/spicy-miso-grilled-chicken/',
#        'https://omnivorescookbook.com/chicken-sweet-potato-stew/',
#        'https://omnivorescookbook.com/instant-pot-whole-chicken/',
#        'https://glebekitchen.com/korean-braised-pork-ribs/',
#        'https://glebekitchen.com/thai-red-chicken-curry/',
#        'https://omnivorescookbook.com/fried-crispy-pork-chop/',
#        'https://glebekitchen.com/korean-style-pork-chops/',
#        'https://thewoksoflife.com/mall-chicken-teriyaki/',
#        'https://omnivorescookbook.com/braised-daikon/'],
#       dtype='object', name='url')
# ['miso chicken with maple and ginger' 'spicy miso grilled chicken'
#  'Creamy Chicken Sweet Potato Stew' 'Instant Pot Whole Chicken'
#  'korean braised pork ribs' 'thai red chicken curry'
#  'Chinese Fried Pork Chops' 'korean style pork chops'
#  'Mall Chicken Teriyaki' 'Chinese Braised Daikon Radish']
# ['images_resized/image_0.jpg', 'images_resized/image_176.jpg', 'images_resized/image_1014.jpg', 'images_resized/image_918.jpg', 'images_resized/image_180.jpg', 'images_resized/image_145.jpg', 'images_resized/image_924.jpg', 'images_resized/image_177.jpg', 'images_resized/image_1383.jpg', 'images_resized/image_843.jpg']

# %%
# !python serve_recs.py
# Out:
# Figure(2000x1000)
# https://thewoksoflife.com/chicken-curry-takeout/ 15-Minute Chicken Curry, Takeout-Style
# https://thewoksoflife.com/20-minute-congee-recipe/ 20-Minute Congee with Pork and Thousand Year-Old Egg (皮蛋瘦肉粥)
# https://omnivorescookbook.com/potato-fried-rice/ Potato Fried Rice (土豆炒饭)
# https://omnivorescookbook.com/drunken-chicken/ Drunken Chicken (醉鸡)
# https://thewoksoflife.com/how-to-velvet-chicken-stir-fry/ How to Velvet Chicken for Stir-Fry
# https://thewoksoflife.com/pork-adobo/ Pork Adobo
# https://omnivorescookbook.com/instant-pot-vegetable-soup/ Instant Pot Vegetable Soup
# https://thewoksoflife.com/seaweed-egg-drop-soup/ Seaweed Egg Drop Soup (紫菜蛋花汤)
# https://thewoksoflife.com/chicken-larb/ Chicken Larb
# https://thewoksoflife.com/shrimp-stir-fry-shanghai/ Shanghai Shrimp Stir-fry - You Bao Xia (油爆虾)
