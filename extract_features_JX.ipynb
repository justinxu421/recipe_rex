# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from save_recipes import agg_data

# %% [markdown]
# # Features
# - Presence of ingredient (0/1)
# - % nutrient (e.g. fat)
#
# # Preprocessing
# - Map all ingredients to a unique index
#
# - Map nutrient info to a category (high fat, high carb)
#
# - Map total time to category (fast, medium, slow)
#
# - Map cuisine to a unique index
#
# # Visualization
# - NA data distribution
#
# - Ingredients distribution
#
# - Time distribution by dataset
#
# - Nutrient info by dataset
#
# - Clustering, compared to title names

# %%
all_dfs_nutrient = agg_data()
# Out:
# 60 datasets found
# /Users/justinxu/recipe_rex/save_recipes.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   all_dfs['nutrients'] = all_dfs['nutrients'].apply(lambda x: yaml.load(x))

# %%
all_dfs_nutrient.columns
# Out:
# Index(['title', 'author', 'url', 'cuisine', 'image_url', 'ingredients',
#        'instructions', 'language', 'ratings', 'reviews', 'site_name',
#        'total_time', 'yields', 'servingSize', 'calories',
#        'carbohydrateContent', 'proteinContent', 'fatContent',
#        'saturatedFatContent', 'cholesterolContent', 'sodiumContent',
#        'sugarContent', 'fiberContent', 'transFatContent',
#        'unsaturatedFatContent'],
#       dtype='object')

# %%
all_dfs_nutrient
# Out:
#                                    title                 author  \
# 0     miso chicken with maple and ginger  romain | glebekitchen
# 1                         tonkotsu ramen  romain | glebekitchen
# 2          garlic ginger grilled chicken  romain | glebekitchen
# 3           tonkotsu ramen broth at home  romain | glebekitchen
# 4                 Japanese chicken curry  romain | glebekitchen
# ..                                   ...                    ...
# 7   Spicy Cumin Lamb Biang Biang Noodles                  Sarah
# 8    Winter Lamb Stew with Spicy Sausage                  Sarah
# 9             Caribbean Spiced Lamb Stew                  Sarah
# 10                            Cumin Lamb                   Judy
# 11              Xi’an Cumin Lamb Burgers                  Sarah
#
#                                                   url   cuisine  \
# 0   https://glebekitchen.com/miso-chicken-with-map...  Japanese
# 1       https://glebekitchen.com/tonkotsu-ramen-home/  Japanese
# 2   https://glebekitchen.com/garlic-ginger-grilled...  Japanese
# 3   https://glebekitchen.com/tonkotsu-ramen-broth-...  Japanese
# 4   https://glebekitchen.com/japanese-chicken-curr...  Japanese
# ..                                                ...       ...
# 7   https://thewoksoflife.com/cumin-lamb-biang-bia...   Chinese
# 8   https://thewoksoflife.com/lamb-stew-spicy-saus...   Chinese
# 9                https://thewoksoflife.com/lamb-stew/   Chinese
# 10              https://thewoksoflife.com/cumin-lamb/   Chinese
# 11      https://thewoksoflife.com/cumin-lamb-burgers/   Chinese
#
#                                             image_url  \
# 0   https://glebekitchen.com/wp-content/uploads/20...
# 1   https://glebekitchen.com/wp-content/uploads/20...
# 2   https://glebekitchen.com/wp-content/uploads/20...
# 3   https://glebekitchen.com/wp-content/uploads/20...
# 4   https://glebekitchen.com/wp-content/uploads/20...
# ..                                                ...
# 7   https://thewoksoflife.com/wp-content/uploads/2...
# 8   https://thewoksoflife.com/wp-content/uploads/2...
# 9   https://thewoksoflife.com/wp-content/uploads/2...
# 10  https://thewoksoflife.com/wp-content/uploads/2...
# 11  https://thewoksoflife.com/wp-content/uploads/2...
#
#                                           ingredients  \
# 0   ['4 chicken breasts (boneless but with the ski...
# 1   ['8 cups tonkotsu pork broth ( - recipe link b...
# 2   ['1/2 cup soy sauce', '2 Tbsp sake', '2 Tbsp g...
# 3   ['6 lbs pork bones (with a little meat on them...
# 4   ['1 lb chicken thighs (boneless, skinless and ...
# ..                                                ...
# 7   ['1 1/2 cups bread flour', '1/4 teaspoon salt'...
# 8   ['2 tablespoons olive oil (divided)', '½ pound...
# 9   ['4 pounds goat or lamb shank ((1.8kg, cut int...
# 10  ['1 pound lamb ((450g, preferably shoulder, cu...
# 11  ['1 tablespoon cumin seeds', '1 teaspoon Sichu...
#
#                                          instructions language  ratings  \
# 0   Combine the miso, sake, mirin, maple syrup, se...    en-US     5.00
# 1   Chashu pork belly\nCombine the soy, sake, miri...    en-US     4.88
# 2   Combine all the ingredients except the chicken...    en-US     5.00
# 3   Place the pork bones in a large stock pot and ...    en-US     4.59
# 4   Prep your vegetables. Slice the onion into 1/8...    en-US     5.00
# ..                                                ...      ...      ...
# 7   First, make the noodle dough. In the bowl of a...    en-US     4.97
# 8   Heat 1 tablespoon olive oil in a large pot or ...    en-US     5.00
# 9   Put the meat in a large bowl, and toss with al...    en-US     5.00
# 10  Pad lamb dry with paper towel before cutting. ...    en-US     4.80
# 11  In a dry pan, toast the cumin seeds, sichuan p...    en-US     5.00
#
#     reviews  ... carbohydrateContent proteinContent fatContent  \
# 0       NaN  ...                10 g           49 g       12 g
# 1       NaN  ...               108 g           33 g       71 g
# 2       NaN  ...                 9 g           43 g       32 g
# 3       NaN  ...                 1 g            NaN        NaN
# 4       NaN  ...             35.44 g        22.14 g    22.35 g
# ..      ...  ...                 ...            ...        ...
# 7       NaN  ...                45 g           19 g       19 g
# 8       NaN  ...                27 g           27 g       21 g
# 9       NaN  ...                21 g           21 g        8 g
# 10      NaN  ...                 4 g           20 g       38 g
# 11      NaN  ...                32 g           30 g       33 g
#
#    saturatedFatContent cholesterolContent sodiumContent sugarContent  \
# 0                  4 g             144 mg        803 mg          5 g
# 1                 25 g             252 mg       2803 mg         28 g
# 2                  9 g             163 mg       1838 mg          6 g
# 3                  NaN                NaN          1 mg          NaN
# 4              12.11 g          109.79 mg    1536.84 mg       6.68 g
# ..                 ...                ...           ...          ...
# 7                  6 g              36 mg        785 mg          4 g
# 8                  6 g              74 mg        545 mg          6 g
# 9                  1 g              51 mg        858 mg          5 g
# 10                12 g              83 mg        478 mg          1 g
# 11                15 g              85 mg        894 mg          8 g
#
#    fiberContent transFatContent unsaturatedFatContent
# 0           NaN             NaN                   NaN
# 1           4 g             NaN                   NaN
# 2           NaN             NaN                   NaN
# 3           NaN             NaN                   NaN
# 4        5.62 g             NaN                   NaN
# ..          ...             ...                   ...
# 7           3 g             NaN                   NaN
# 8           5 g             NaN                   NaN
# 9           5 g             NaN                   NaN
# 10          1 g             NaN                   NaN
# 11          3 g             NaN                   NaN
#
# [2788 rows x 25 columns]

# %%
# !python save_recipes.py
# Out:
# 60 datasets found
# save_recipes.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   all_dfs['nutrients'] = all_dfs['nutrients'].apply(lambda x: yaml.load(x))

# %%
nutrient_cols = [c for c in all_dfs_nutrient.columns if 'Content' in c]
all_dfs_nutrient[nutrient_cols]
# Out:
#    carbohydrateContent proteinContent fatContent saturatedFatContent  \
# 0                 10 g           49 g       12 g                 4 g
# 1                108 g           33 g       71 g                25 g
# 2                  9 g           43 g       32 g                 9 g
# 3                  1 g            NaN        NaN                 NaN
# 4              35.44 g        22.14 g    22.35 g             12.11 g
# ..                 ...            ...        ...                 ...
# 7                 45 g           19 g       19 g                 6 g
# 8                 27 g           27 g       21 g                 6 g
# 9                 21 g           21 g        8 g                 1 g
# 10                 4 g           20 g       38 g                12 g
# 11                32 g           30 g       33 g                15 g
#
#    cholesterolContent sodiumContent sugarContent fiberContent transFatContent  \
# 0              144 mg        803 mg          5 g          NaN             NaN
# 1              252 mg       2803 mg         28 g          4 g             NaN
# 2              163 mg       1838 mg          6 g          NaN             NaN
# 3                 NaN          1 mg          NaN          NaN             NaN
# 4           109.79 mg    1536.84 mg       6.68 g       5.62 g             NaN
# ..                ...           ...          ...          ...             ...
# 7               36 mg        785 mg          4 g          3 g             NaN
# 8               74 mg        545 mg          6 g          5 g             NaN
# 9               51 mg        858 mg          5 g          5 g             NaN
# 10              83 mg        478 mg          1 g          1 g             NaN
# 11              85 mg        894 mg          8 g          3 g             NaN
#
#    unsaturatedFatContent
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ..                   ...
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
#
# [2788 rows x 10 columns]
