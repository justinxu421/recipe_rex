# %%
import os

# %%
os.listdir('images')[:10]
# Out:
# ['image_1502.jpg',
#  'image_811.jpg',
#  'image_1264.jpg',
#  'image_1270.jpg',
#  'image_805.jpg',
#  'image_1516.jpg',
#  'image_2037.jpg',
#  'image_1258.jpg',
#  'image_193.jpg',
#  'image_187.jpg']

# %%
from PIL import Image

def center_crop(im):
    width, height = im.size
    if width < height:
        a = 0
        b = (height - width) // 2
        c = width
        d = height - b
        return im.crop((a, b, c, d))
    else:
        a = (width - height) // 2
        b = 0
        c = width - a
        d = height
        return im.crop((a, b, c, d))
        
for image in os.listdir('images')[:10]:
    if '.jpg' in image:
        im = Image.open(f"images/{image}")
        im1 = center_crop(im)
        im1 = im1.resize((400, 400))
        im1.save(f"images_resized/{image}")

# %%
im = Image.open(f"images/image_1696.jpg")
im1 = center_crop(im)
im1 = im1.resize((400, 400))
im1.save(f"images_resized/{image}")

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FD30DDFB0A0>

# %%
# !python center_crop_resize_images.py
# Out:
# image_331.jpg
