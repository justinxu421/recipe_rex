# %%
import pandas as pd
import pathlib

# %%
datasets = pathlib.Path("data").rglob("*.csv")
datasets = [d.as_posix() for d in datasets]
print(f"{len(datasets)} datasets found")

### Features
# Presence of ingredient (0/1)
# % nutrient (e.g. fat)

### Preprocessing
# Map all ingredients to a unique index

# Map nutrient info to a category (high fat, high carb)

# Map total time to category (fast, medium, slow)

# Map cuisine to a unique index

### Visualization
# NA data distribution

# Ingredients distribution

# Time distribution by dataset

# Nutrient info by dataset

# Clustering, compared to title names
# Out:
# 60 datasets found

# %%
pd.read_csv(datasets[0])
# Out:
#                                         title                 author  \
# 0          miso chicken with maple and ginger  romain | glebekitchen
# 1                              tonkotsu ramen  romain | glebekitchen
# 2               garlic ginger grilled chicken  romain | glebekitchen
# 3                tonkotsu ramen broth at home  romain | glebekitchen
# 4                      Japanese chicken curry  romain | glebekitchen
# 5                             chicken karaage  romain | glebekitchen
# 6                         Curry chicken ramen  romain | glebekitchen
# 7                                 beef tataki  romain | glebekitchen
# 8                         momofuku pork belly  romain | glebekitchen
# 9                 gyudon - japanese beef bowl  romain | glebekitchen
# 10            japadog style terimayo hot dogs  romain | glebekitchen
# 11                         japanese miso soup  romain | glebekitchen
# 12  japanese grilled chicken yakitori skewers  romain | glebekitchen
# 13                miso ramen with chashu pork  romain | glebekitchen
# 14                      30 minute curry ramen  romain | glebekitchen
# 15                             japanese gyoza  romain | glebekitchen
#
#                                                   url           cuisine  \
# 0   https://glebekitchen.com/miso-chicken-with-map...          Japanese
# 1       https://glebekitchen.com/tonkotsu-ramen-home/          Japanese
# 2   https://glebekitchen.com/garlic-ginger-grilled...          Japanese
# 3   https://glebekitchen.com/tonkotsu-ramen-broth-...          Japanese
# 4   https://glebekitchen.com/japanese-chicken-curr...          Japanese
# 5   https://glebekitchen.com/chicken-karaage-japan...          Japanese
# 6       https://glebekitchen.com/curry-chicken-ramen/          Japanese
# 7   https://glebekitchen.com/sous-vide-steak-tatak...          Japanese
# 8       https://glebekitchen.com/momofuku-pork-belly/  Chinese,Japanese
# 9   https://glebekitchen.com/gyudon-japanese-beef-...          Japanese
# 10  https://glebekitchen.com/japadog-style-terimay...          Japanese
# 11       https://glebekitchen.com/japanese-miso-soup/          Japanese
# 12  https://glebekitchen.com/japanese-chicken-yaki...              main
# 13  https://glebekitchen.com/miso-ramen-with-chash...          Japanese
# 14    https://glebekitchen.com/30-minute-curry-ramen/          Japanese
# 15           https://glebekitchen.com/japanese-gyoza/          Japanese
#
#                                             image_url  \
# 0   https://glebekitchen.com/wp-content/uploads/20...
# 1   https://glebekitchen.com/wp-content/uploads/20...
# 2   https://glebekitchen.com/wp-content/uploads/20...
# 3   https://glebekitchen.com/wp-content/uploads/20...
# 4   https://glebekitchen.com/wp-content/uploads/20...
# 5   https://glebekitchen.com/wp-content/uploads/20...
# 6   https://glebekitchen.com/wp-content/uploads/20...
# 7   https://glebekitchen.com/wp-content/uploads/20...
# 8   https://glebekitchen.com/wp-content/uploads/20...
# 9   https://glebekitchen.com/wp-content/uploads/20...
# 10  https://glebekitchen.com/wp-content/uploads/20...
# 11  https://glebekitchen.com/wp-content/uploads/20...
# 12  https://glebekitchen.com/wp-content/uploads/20...
# 13  https://glebekitchen.com/wp-content/uploads/20...
# 14  https://glebekitchen.com/wp-content/uploads/20...
# 15  https://glebekitchen.com/wp-content/uploads/20...
#
#                                           ingredients  \
# 0   ['4 chicken breasts (boneless but with the ski...
# 1   ['8 cups tonkotsu pork broth ( - recipe link b...
# 2   ['1/2 cup soy sauce', '2 Tbsp sake', '2 Tbsp g...
# 3   ['6 lbs pork bones (with a little meat on them...
# 4   ['1 lb chicken thighs (boneless, skinless and ...
# 5   ['8 boneless chicken thighs with the skin on (...
# 6   ['3 boneless chicken thighs ( - with the skin ...
# 7   ["12-14 oz good quality top sirloin ( - cut 1 ...
# 8   ['3 lbs meaty pork belly', '1/4 cup kosher sal...
# 9   ['12 oz thinly sliced ribeye or sirloin', '1/2...
# 10  ['6 large hot dogs (- whatever you like but bi...
# 11  ['5 cups water', '2 1/2 tsp hon-dashi (- insta...
# 12  ['8 boneless skinless chicken thighs ( - cut i...
# 13  ['2 lb pork belly (in one piece, skin removed)...
# 14  ['8 oz top sirloin ( - can use chicken breast ...
# 15  ['10 oz ground pork', '4 cups napa cabbage (su...
#
#                                          instructions language  \
# 0   Combine the miso, sake, mirin, maple syrup, se...    en-US
# 1   Chashu pork belly\nCombine the soy, sake, miri...    en-US
# 2   Combine all the ingredients except the chicken...    en-US
# 3   Place the pork bones in a large stock pot and ...    en-US
# 4   Prep your vegetables. Slice the onion into 1/8...    en-US
# 5   Cut each chicken thigh into 3-4 pieces. You ar...    en-US
# 6   Put a big pot of water on to boil to cook the ...    en-US
# 7   Sous vide the steak and cook the steaks\nSalt ...    en-US
# 8   Combine the sugar, salt and black pepper and m...    en-US
# 9   gyudon\nCombine dashi, mirin, sake, soy and su...    en-US
# 10  Teriyaki sauce\nCombine all the ingredients ex...    en-US
# 11  If you are adding wakame, bring a small amount...    en-US
# 12  Yakitori\nSkewer a piece of chicken onto a ske...    en-US
# 13  Chashu pork\nPre-heat your oven to 290F.\nComb...    en-US
# 14  Put a pot of water on to boil for the noodles\...    en-US
# 15  Prep the dipping sauce by mixing two parts soy...    en-US
#
#                                             nutrients  ratings  reviews  \
# 0   {'servingSize': '4 servings', 'calories': '368...     5.00      NaN
# 1   {'servingSize': '4 servings', 'calories': '126...     4.88      NaN
# 2   {'servingSize': '4 servings', 'calories': '524...     5.00      NaN
# 3   {'servingSize': '4 servings', 'calories': '8 k...     4.59      NaN
# 4   {'calories': '418.35 kcal', 'carbohydrateConte...     5.00      NaN
# 5   {'servingSize': '4 servings', 'calories': '612...     5.00      NaN
# 6   {'servingSize': '2 servings', 'calories': '843...     5.00      NaN
# 7   {'servingSize': '4 servings', 'calories': '132...     5.00      NaN
# 8   {'servingSize': '8 g', 'calories': '893 kcal',...     4.64      NaN
# 9   {'servingSize': '2 servings', 'calories': '351...     5.00      NaN
# 10  {'servingSize': '6 g', 'calories': '470 kcal',...     5.00      NaN
# 11  {'servingSize': '4 servings', 'calories': '53 ...     4.50      NaN
# 12  {'servingSize': '8 servings', 'calories': '174...    -1.00      NaN
# 13  {'servingSize': '4 servings', 'calories': '198...     4.17      NaN
# 14  {'servingSize': '2 servings', 'calories': '447...     5.00      NaN
# 15  {'servingSize': '35 gyoza', 'calories': '47 kc...    -1.00      NaN
#
#         site_name  total_time         yields
# 0   glebe kitchen          90   4 serving(s)
# 1   glebe kitchen         750   4 serving(s)
# 2   glebe kitchen          70   4 serving(s)
# 3   glebe kitchen         750   8 serving(s)
# 4   glebe kitchen          60   4 serving(s)
# 5   glebe kitchen          75   4 serving(s)
# 6   glebe kitchen          40   2 serving(s)
# 7   glebe kitchen         122   4 serving(s)
# 8   glebe kitchen        1680   8 serving(s)
# 9   glebe kitchen          20   2 serving(s)
# 10  glebe kitchen          50   6 serving(s)
# 11  glebe kitchen          10   4 serving(s)
# 12  glebe kitchen          50   8 serving(s)
# 13  glebe kitchen         170   4 serving(s)
# 14  glebe kitchen          30   2 serving(s)
# 15  glebe kitchen          50  35 serving(s)
