# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

# %%
# embeddings_df_scaled = pd.read_csv('clean_data/embeddings_mvp_scaled.csv', index_col = 'url')
# url_index_mapping = pd.read_csv('clean_data/url_index_mapping.csv', index_col = 'url')

# %%
from serve_recs import KNNRecSys
rec_sys = KNNRecSys()

urls, image_paths = rec_sys.sample_urls(10)
print(urls, image_paths)

rec_sys.plot_images(image_paths)
# Out:
# Index(['https://omnivorescookbook.com/recipes/tomato-noodle-soup/',
#        'https://thewoksoflife.com/chinese-stuffed-eggplant/',
#        'https://thewoksoflife.com/three-cup-chicken-san-bei-ji/',
#        'https://thewoksoflife.com/chinese-hot-dog-buns/',
#        'https://omnivorescookbook.com/shu-mai/',
#        'https://thewoksoflife.com/butterfly-shrimp-bacon/',
#        'https://thewoksoflife.com/thai-green-papaya-salad/',
#        'https://mykoreankitchen.com/pan-fried-zucchini/',
#        'https://glebekitchen.com/authentic-pho-ga-vietnamese-chicken-noodle-soup/',
#        'https://thewoksoflife.com/stuffed-chicken-breast-sticky-rice/'],
#       dtype='object', name='url') ['images_resized/image_1040.jpg', 'images_resized/image_1691.jpg', 'images_resized/image_1420.jpg', 'images_resized/image_1595.jpg', 'images_resized/image_779.jpg', 'images_resized/image_1991.jpg', 'images_resized/image_1619.jpg', 'images_resized/image_190.jpg', 'images_resized/image_26.jpg', 'images_resized/image_1344.jpg']

# %%
# sample some urls
urls = ['https://omnivorescookbook.com/chinese-egg-rolls/',
       'https://glebekitchen.com/miso-ramen-with-chashu-pork/',
       'https://omnivorescookbook.com/pineapple-buns/',
       'https://omnivorescookbook.com/easy-swiss-chard-stir-fry/',
       'https://thewoksoflife.com/stuffed-chicken-breast-sticky-rice/',
       'https://glebekitchen.com/spicy-miso-grilled-chicken/',
       'https://thewoksoflife.com/shrimp-lo-mein/',
       'https://thewoksoflife.com/stir-fried-cabbage-glass-noodles/',
       'https://glebekitchen.com/indian-restaurant-madras-curry/',
       'https://thewoksoflife.com/honey-sriracha-roasted-brussels-sprouts/']

rec_urls, rec_titles, recs_image_paths = rec_sys.get_recs(urls)
print(rec_urls)
print(rec_titles)
print(recs_image_paths)

rec_sys.plot_images(recs_image_paths)
# Out:
# Index(['https://thewoksoflife.com/chicken-curry-takeout/',
#        'https://thewoksoflife.com/20-minute-congee-recipe/',
#        'https://omnivorescookbook.com/potato-fried-rice/',
#        'https://omnivorescookbook.com/drunken-chicken/',
#        'https://thewoksoflife.com/how-to-velvet-chicken-stir-fry/',
#        'https://thewoksoflife.com/pork-adobo/',
#        'https://omnivorescookbook.com/instant-pot-vegetable-soup/',
#        'https://thewoksoflife.com/seaweed-egg-drop-soup/',
#        'https://thewoksoflife.com/chicken-larb/',
#        'https://thewoksoflife.com/shrimp-stir-fry-shanghai/'],
#       dtype='object', name='url')
# ['15-Minute Chicken Curry, Takeout-Style'
#  '20-Minute Congee with Pork and Thousand Year-Old Egg (皮蛋瘦肉粥)'
#  'Potato Fried Rice (土豆炒饭)' 'Drunken Chicken (醉鸡)'
#  'How to Velvet Chicken for Stir-Fry' 'Pork Adobo'
#  'Instant Pot Vegetable Soup' 'Seaweed Egg Drop Soup (紫菜蛋花汤)'
#  'Chicken Larb' 'Shanghai Shrimp Stir-fry - You Bao Xia (油爆虾)']
# ['images_resized/image_1329.jpg', 'images_resized/image_1556.jpg', 'images_resized/image_1121.jpg', 'images_resized/image_745.jpg', 'images_resized/image_1380.jpg', 'images_resized/image_1865.jpg', 'images_resized/image_1049.jpg', 'images_resized/image_1828.jpg', 'images_resized/image_1372.jpg', 'images_resized/image_2007.jpg']

# %%
# !python serve_recs.py
# Out:
# Figure(2000x1000)
# https://thewoksoflife.com/chicken-curry-takeout/ 15-Minute Chicken Curry, Takeout-Style
# https://thewoksoflife.com/20-minute-congee-recipe/ 20-Minute Congee with Pork and Thousand Year-Old Egg (皮蛋瘦肉粥)
# https://omnivorescookbook.com/potato-fried-rice/ Potato Fried Rice (土豆炒饭)
# https://omnivorescookbook.com/drunken-chicken/ Drunken Chicken (醉鸡)
# https://thewoksoflife.com/how-to-velvet-chicken-stir-fry/ How to Velvet Chicken for Stir-Fry
# https://thewoksoflife.com/pork-adobo/ Pork Adobo
# https://omnivorescookbook.com/instant-pot-vegetable-soup/ Instant Pot Vegetable Soup
# https://thewoksoflife.com/seaweed-egg-drop-soup/ Seaweed Egg Drop Soup (紫菜蛋花汤)
# https://thewoksoflife.com/chicken-larb/ Chicken Larb
# https://thewoksoflife.com/shrimp-stir-fry-shanghai/ Shanghai Shrimp Stir-fry - You Bao Xia (油爆虾)
