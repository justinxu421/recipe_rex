# %%
import pandas as pd

# %%
pd.read_csv('data/glebe_kitchen/glebe_indian.csv')
# Out:
#                                             title                 author  \
# 0                                  vindaloo paste  romain | glebekitchen
# 1                                 beef rogan josh  romain | glebekitchen
# 2       achari chicken curry - Indian hotel style  romain | glebekitchen
# 3        indian restaurant hariyali chicken curry  romain | glebekitchen
# 4                            ceylon chicken curry  romain | glebekitchen
# ..                                            ...                    ...
# 97                 indian restaurant madras curry          glebe kitchen
# 98               Lamb madras - Indian hotel style  romain | glebekitchen
# 99   kachumber - indian tomato and cucumber salad  romain | glebekitchen
# 100           murgir jhol - bengali chicken curry  romain | glebekitchen
# 101                               lamb rogan josh  romain | glebekitchen
#
#                                                    url cuisine  \
# ...
